# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
TICKER = 'SPY'
WINDOW = 200

def get_data():
    df = yf.download(TICKER)
    df.columns = df.columns.get_level_values(0)

    # add the moving average column
    df['MA'] = df['Close'].rolling(WINDOW).mean()

    # plot the information
    plt.plot(df['Close'])
    plt.plot(df['MA'])
    plt.title(f'{TICKER} Close Price With {WINDOW} Moving Average')

    return df.dropna()

def main():
    df = get_data()
    return df

main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume  \
# Date
# 1993-11-11   26.277445   26.419102   26.259738   26.348274     88900
# 1993-11-12   26.401384   26.489920   26.312849   26.330556    108200
# 1993-11-15   26.383673   26.454501   26.312844   26.454501    243300
# 1993-11-16   26.507635   26.525342   26.330563   26.436806    492600
# 1993-11-17   26.365967   26.525331   26.295138   26.525331     39600
# ...                ...         ...         ...         ...       ...
# 2025-04-21  513.880005  521.700012  508.459991  521.159973  69368100
# 2025-04-22  527.250000  529.299988  519.190002  520.140015  75948100
# 2025-04-23  535.419983  545.429993  533.880005  540.429993  90590700
# 2025-04-24  546.690002  547.429993  535.450012  536.719971  64150400
# 2025-04-25  550.640015  551.049988  543.690002  546.650024  61025700
#
# Price               MA
# Date
# 1993-11-11   25.383038
# 1993-11-12   25.392782
# 1993-11-15   25.401569
# 1993-11-16   25.410714
# 1993-11-17   25.417846
# ...                ...
# 2025-04-21  570.276754
# 2025-04-22  570.181573
# 2025-04-23  570.111491
# 2025-04-24  570.094589
# 2025-04-25  570.094763
#
# [7917 rows x 6 columns]
